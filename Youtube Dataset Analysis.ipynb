# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot

# %%
df=pd.read_csv('youtube.csv')

# %%
df.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers
# 0  1st  A++                       Zee TV         82757    18752951  \
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
pd.options.display.float_format='{:.2f}'.format
df.describe()
# Out:
#          Video views
# count        5000.00
# mean   1071449400.15
# std    2003843972.12
# min            75.00
# 25%     186232945.75
# 50%     482054780.00
# 75%    1124367826.75
# max   47548839843.00

# %%
df.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers
# 0    1st  A++                       Zee TV         82757    18752951  \
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
df.replace('--',np.nan,regex=True,inplace=True)

# %%
df.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers
# 0    1st  A++                       Zee TV         82757    18752951  \
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
df.isnull().sum()
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
missing=df.isnull().sum()*100/len(df)
missing
# Out:
# Rank            0.00
# Grade           0.00
# Channel name    0.00
# Video Uploads   0.12
# Subscribers     7.74
# Video views     0.00
# dtype: float64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.dropna(axis=0,inplace=True)

# %%
df.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers
# 0    1st  A++                       Zee TV         82757    18752951  \
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.tail(5)
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %%
df['Rank']=df['Rank'].str[0:-2]

# %%
df.tail(5)
# Out:
#        Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998   B+         Mastersaint           110     3265735    311758426
# 4998  4,999   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000   B+           SehatAQUA           254       21172     73312511

# %%
df['Rank']=df['Rank'].str.replace(',','').astype('int')

# %%
df.tail(5)
# Out:
#       Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4996   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4997   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4998   B+         Mastersaint           110     3265735    311758426
# 4998  4999   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5000   B+           SehatAQUA           254       21172     73312511

# %%
df.dtypes
# Out:
# Rank              int32
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
df['Video Uploads']=df['Video Uploads'].astype('int')

# %%
df['Subscribers']=df['Subscribers'].astype('int')

# %%
df['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
df['Grade']=df['Grade'].map({'A++ ':5, 'A+ ':4, 'A ':3, 'A- ':2, 'B+ ':1})

# %%
df.head(10)
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers
# 0     1      5                      Zee TV          82757     18752951  \
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
# 5     6      5                  Movieclips          30243     17149705
# 6     7      5                  netd müzik           8500     11373567
# 7     8      5       ABS-CBN Entertainment         100147     12149206
# 8     9      5             Ryan ToysReview           1140     16082927
# 9    10      5                 Zee Marathi          74607      2841811
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433
# 5  16618094724
# 6  23898730764
# 7  17202609850
# 8  24518098041
# 9   2591830307

# %%
df['Avg Views']=df['Video views']/df['Video Uploads']

# %%
df.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers
# 0     1      5                      Zee TV          82757     18752951  \
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
#
#    Video views   Avg Views
# 0  20869786591   252181.53
# 1  47548839843  3755535.89
# 2   9793305082 26255509.60
# 3  22675948293   829921.62
# 4  26273668433   714813.05

# %%
s= df.groupby(['Channel name'], as_index=False)['Avg Views'].sum().sort_values(by='Avg Views', ascending=False).head(5)

sns.set(rc={'figure.figsize':(12,5)})
sns.barplot(data = s, x = 'Channel name',y= 'Avg Views')
# Out:
# <Axes: xlabel='Channel name', ylabel='Avg Views'>

# %% [markdown]
# cocoz toon is having the maximum audience retention capability and NBA LeB is performing the worst.

# %%
df.sort_values(by='Video Uploads',ascending=False).head()
# Out:
#       Rank  Grade Channel name  Video Uploads  Subscribers  Video views
# 3453  3454      1   AP Archive         422326       746325    548619569  \
# 1149  1150      2     YTN NEWS         355996       820108   1640347646
# 2223  2224      1    SBS Drama         335521      1418619   1565758044
# 323    324      3     GMA News         269065      2599175   2786949164
# 2956  2957      1          MLB         267649      1434206   1329206392
#
#       Avg Views
# 3453    1299.04
# 1149    4607.77
# 2223    4666.65
# 323    10357.90
# 2956    4966.23

# %% [markdown]
#     AP Archive uploads maximum videos

# %%
df.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views', 'Avg Views'],
#       dtype='object')

# %%
sns.barplot(x='Grade',y='Video Uploads',data=df)
# Out:
# <Axes: xlabel='Grade', ylabel='Video Uploads'>

# %% [markdown]
# Grade 5 is having maximum video uploads

# %%
sns.barplot(x='Grade',y='Avg Views',data=df)
# Out:
# <Axes: xlabel='Grade', ylabel='Avg Views'>

# %% [markdown]
# Grade 4 is having maximum Avg Views

# %%
sns.barplot(x='Grade',y='Subscribers',data=df)
# Out:
# <Axes: xlabel='Grade', ylabel='Subscribers'>

# %% [markdown]
# Grade 5 has maximum subscribers

# %% [markdown]
# #  Final Report

# %% [markdown]
# cocoz toon is having the maximum audience retention capability and NBA LeB is performing the worst.
#
# AP Archive uploads maximum videos
#
# Grade 5 is having maximum video uploads
#
# Grade 4 is having maximum Avg Views
#
# Grade 5 has maximum subscribers
